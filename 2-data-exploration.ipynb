# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from scipy import stats
import warnings

# %% [markdown]
# ### Load the dataset

# %%
train_file_path = "input/house-prices-advanced-regression-techniques/train.csv"
df_train = pd.read_csv(train_file_path)

# %% [markdown]
# ### Correlation matrix

# %%
# compute correlations only on numeric columns to avoid trying to convert strings like 'RL' to float
corrmat = df_train.select_dtypes(include=[np.number]).corr()

# mask the upper triangle for better readability
mask = np.triu(np.ones_like(corrmat, dtype=bool))

f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(
	corrmat,
	mask=mask,
	vmax=.8,
	square=True,
	cmap='coolwarm',
	linewidths=.5,
	cbar_kws={"shrink": .5}
)
ax.set_title("Correlation matrix (numeric features)")
plt.tight_layout()

# %%
# Trier pour voir les plus fortes corrélations avec SalePrice
print("Top 10 des variables les plus importantes :")
print(corrmat['SalePrice'].sort_values(ascending=False).head(15))
# Out:
# Top 10 des variables les plus importantes :
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# Name: SalePrice, dtype: float64
